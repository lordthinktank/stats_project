# %%
from setup import *
import json

df = pd.read_json('cards.json')

# %%
display(df.drop('artist', axis=1))
# Out:
#       attack classes  collectible collectionText   cost     dbfId  durability  \
# 0        nan     NaN          nan            NaN  1.000 39762.000         nan
# 1        nan     NaN          nan            NaN  0.000   313.000         nan
# 2      2.000     NaN          nan            NaN  3.000  2311.000         nan
# 3      6.000     NaN        1.000            NaN  6.000  2736.000         nan
# 4     10.000     NaN        1.000            NaN 10.000 38521.000         nan
# 5      9.000     NaN          nan            NaN  9.000  1777.000         nan
# 6        nan     NaN          nan            NaN    nan 39045.000         nan
# 7        nan     NaN          nan            NaN    nan  2452.000         nan
# 8        nan     NaN          nan            NaN    nan  2166.000         nan
# 9        nan     NaN          nan            NaN  2.000 36744.000         nan
# 10     3.000     NaN        1.000            NaN  3.000  2519.000         nan
# ...
